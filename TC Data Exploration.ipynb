# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Data

# %%
cb = pd.read_csv('questionnaire_codebook.csv')
    
q2 = pd.read_csv('tidy_data_questionnaire_section_2.csv')
q3 = pd.read_csv('tidy_data_questionnaire_section_3.csv')
q4 = pd.read_csv('tidy_data_questionnaire_section_4.csv')
q5 = pd.read_csv('tidy_data_questionnaire_section_5.csv')
q7 = pd.read_csv('tidy_data_questionnaire_section_7.csv')
q8 = pd.read_csv('tidy_data_questionnaire_section_8.csv')

# %% [markdown]
# ## Initial Exploration
# ### Identify what information each dataframe provides

# %%
#Plot characteristics
#Do NaN values in 'no_of_toilets' field imply zero toilets? As minimum non-NaN value is 1.
q2.head()
# Out:
#          id respondent     sex  plot_months type_of_property  no_of_hhs  \
# 0  id_00001        NaN     NaN          NaN              NaN        NaN
# 1  id_00002   landlord  female          1.0      residential        4.0
# 2  id_00003     tenant    male         48.0      residential        4.0
# 3  id_00004     tenant  female        192.0      residential       13.0
# 4  id_00005   landlord  female          5.0      residential        4.0
#
#    no_of_ppl s2q9a54     type_of_toilet  no_of_toilets add_toilets  \
# 0        NaN     NaN                NaN            NaN         NaN
# 1       25.0     NaN  pit_latrine_lined            1.0         NaN
# 2       22.0     NaN                NaN            NaN       yes_4
# 3       38.0     NaN  pit_latrine_lined            1.0         NaN
# 4       14.0     NaN  pit_latrine_lined            1.0       yes_2
#
#             water_source          water_source_other   latitude  longitude  \
# 0                    NaN                         NaN        NaN        NaN
# 1          other_specify  Lusaka water connected tap        NaN        NaN
# 2  individual_connection                         NaN        NaN        NaN
# 3            water_kiosk                         NaN -15.431633  28.245173
# 4            water_kiosk                         NaN -15.430095  28.242203
#
#    accuracy  altitude
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       3.9    1289.8
# 4       3.9    1268.9

# %%
#calculating average people per household
total_ppl = q2['no_of_ppl'].sum()
total_hh = q2['no_of_hhs'].sum()
avg_ppl_hh = total_ppl/total_hh

print('Total people: {}'.format(total_ppl))
print('Total households: {}'.format(total_hh))
print('Avg. People per household: {}'.format(avg_ppl_hh))
# Out:
# Total people: 215097.0
# Total households: 53884.0
# Avg. People per household: 3.991852869126271

# %%
#Toilet user profile
q3.head()
# Out:
#          id      toilet_user  no_of_toilet_user    solid_waste_disp
# 0  id_00001              NaN                NaN                 NaN
# 1  id_00002    children_male                4.0  bin_collected_CBEs
# 2  id_00002  children_female               13.0  bin_collected_CBEs
# 3  id_00002      adults_male                3.0  bin_collected_CBEs
# 4  id_00002    adults_female                4.0  bin_collected_CBEs

# %%
#Toilet Maintenance
#id is unique in this df. But which toilet do each of the fields apply to??
q4.head()
# Out:
#          id  age_toilet_1  age_toilet_2  age_toilet_3    when_toilet_full  \
# 0  id_00001           NaN           NaN           NaN                 NaN
# 1  id_00002          36.0           NaN           NaN     empty_and_reuse
# 2  id_00003           NaN           NaN           NaN                 NaN
# 3  id_00004          24.0           NaN           NaN  bury_and_build_new
# 4  id_00005          60.0           NaN           NaN     empty_and_reuse
#
#   ever_emptied            when_last_emptied    know_emptying_service  \
# 0          NaN                          NaN                      NaN
# 1          yes  between_five_and_six_months  friend_familiy_neighbor
# 2          NaN                          NaN                      NaN
# 3           no                          NaN                      NaN
# 4           no                          NaN                      NaN
#
#   who_emptied  how_often_emptied_mo how_often_emptied_other  \
# 0         NaN                   NaN                     NaN
# 1       other                   NaN                     NaN
# 2         NaN                   NaN                     NaN
# 3         NaN                   NaN                     NaN
# 4         NaN                   NaN                     NaN
#
#    when_next_full_mo why_never_emptied
# 0                NaN               NaN
# 1                6.0               NaN
# 2                NaN               NaN
# 3                7.0   never_been_full
# 4                NaN   never_been_full

# %%
#Characteristics of first toilet
q5.head()
# Out:
#          id    roof_material slab_material slab_material_other  \
# 0  id_00001              NaN           NaN                 NaN
# 1  id_00002      iron_sheets      concrete                 NaN
# 2  id_00003              NaN           NaN                 NaN
# 3  id_00004          no_roof      concrete                 NaN
# 4  id_00005  asbestos_sheets      concrete                 NaN
#
#      user_interface user_interface_other  containment containment_other  \
# 0               NaN                  NaN          NaN               NaN
# 1  dry_toilet_squat                  NaN  pit_latrine               NaN
# 2               NaN                  NaN          NaN               NaN
# 3  dry_toilet_squat                  NaN  pit_latrine               NaN
# 4  dry_toilet_squat                  NaN  pit_latrine               NaN
#
#      fill_level emptying_feasible overflow_flooding vacuum_tanker_access  \
# 0           NaN               NaN               NaN                  NaN
# 1   almost_full               yes                no                  yes
# 2           NaN                no               NaN                  NaN
# 3   almost_full               yes                no                  yes
# 4  almost_empty                no                no                  yes
#
#   light_truck_access push_cart_access
# 0                NaN              NaN
# 1                yes              yes
# 2                NaN              NaN
# 3                yes              yes
# 4                yes              yes

# %%
#Characteristics of second toilet
q7.head()
# Out:
#          id roof_material_toilet_2 slab_material_toilet_2  \
# 0  id_00001                    NaN                    NaN
# 1  id_00002                    NaN                    NaN
# 2  id_00003                    NaN                    NaN
# 3  id_00004                    NaN                    NaN
# 4  id_00005                    NaN                    NaN
#
#   slab_material_other_toilet_2 user_interface_toilet_2  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
#
#   user_interface_other_toilet_2 containment_toilet_2  \
# 0                           NaN                  NaN
# 1                           NaN                  NaN
# 2                           NaN                  NaN
# 3                           NaN                  NaN
# 4                           NaN                  NaN
#
#   containment_other_toilet_2 fill_level_toilet_2 emptying_feasible_toilet_2  \
# 0                        NaN                 NaN                        NaN
# 1                        NaN                 NaN                        NaN
# 2                        NaN                 NaN                        NaN
# 3                        NaN                 NaN                        NaN
# 4                        NaN                 NaN                        NaN
#
#   overflow_flooding_toilet_2 vacuum_tanker_access_toilet_2  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
#   light_truck_access_toilet_2 push_cart_access_toilet_2
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN

# %%
#Characteristics of third toilet
q8.head()
# Out:
#          id roof_material_toilet_3 slab_material_toilet_3  \
# 0  id_00001                    NaN                    NaN
# 1  id_00002                    NaN                    NaN
# 2  id_00003                    NaN                    NaN
# 3  id_00004                    NaN                    NaN
# 4  id_00005                    NaN                    NaN
#
#   slab_material_other_toilet_3 user_interface_toilet_3  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
#
#    user_interface_other_toilet_3 containment_toilet_3  \
# 0                            NaN                  NaN
# 1                            NaN                  NaN
# 2                            NaN                  NaN
# 3                            NaN                  NaN
# 4                            NaN                  NaN
#
#   containment_other_toilet_3 fill_level_toilet_3 emptying_feasible_toilet_3  \
# 0                        NaN                 NaN                        NaN
# 1                        NaN                 NaN                        NaN
# 2                        NaN                 NaN                        NaN
# 3                        NaN                 NaN                        NaN
# 4                        NaN                 NaN                        NaN
#
#   overflow_flooding_toilet_3 vacuum_tanker_access_toilet_3  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
#   light_truck_access_toilet_3 push_cart_access_toilet_3
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN

# %% [markdown]
# ### Duplicates in ID column

# %%
#Which IDs (plots) are duplicated - looks like majority are due to type of toilet changing i.e from used to disused
q2_id_dups = q2[q2['id'].duplicated(keep=False)]
q2_id_dups.head(6)
# Out:
#           id respondent     sex  plot_months type_of_property  no_of_hhs  \
# 6   id_00007        NaN     NaN          NaN      residential        7.0
# 7   id_00007        NaN     NaN          NaN      residential        7.0
# 18  id_00018   landlord  female         12.0      residential       13.0
# 19  id_00018   landlord  female         12.0      residential       13.0
# 22  id_00021   landlord    male         12.0      residential        5.0
# 23  id_00021   landlord    male         12.0      residential        5.0
#
#     no_of_ppl s2q9a54     type_of_toilet  no_of_toilets add_toilets  \
# 6         6.0     NaN  pit_latrine_lined            1.0       yes_1
# 7         6.0     NaN     disused_buried            1.0       yes_1
# 18       31.0     NaN  pit_latrine_lined            1.0         NaN
# 19       31.0     NaN     disused_buried            1.0         NaN
# 22       25.0     NaN  pit_latrine_lined            1.0       yes_1
# 23       25.0     NaN     disused_buried            1.0       yes_1
#
#    water_source water_source_other   latitude  longitude  accuracy  altitude
# 6       private                NaN        NaN        NaN       NaN       NaN
# 7       private                NaN        NaN        NaN       NaN       NaN
# 18  water_kiosk                NaN        NaN        NaN       NaN       NaN
# 19  water_kiosk                NaN        NaN        NaN       NaN       NaN
# 22      private                NaN -15.430098  28.241942       4.9    1289.4
# 23      private                NaN -15.430098  28.241942       4.9    1289.4

# %% [markdown]
# ### Location Plots

# %%
#drop plot id_10380 as its lat/long is way outside our geographic range
i = q2[(q2['id'] == 'id_10380')].index
q2 = q2.drop(i)

#Initial location of all plots with non-null lat/lons
plt.figure(figsize=(18,12))
plt.scatter(x=q2['longitude'],y=q2['latitude'],alpha = 0.5)
axes = plt.gca()
axes.set_title('Location Plots')
axes.set_xlabel('Longitude')
axes.set_ylabel('Latitude')
axes.set_xlim([28.20,28.27])
axes.set_ylim([-15.458,-15.415])

plt.show()

# %%
#Location of different types of toilet - can have multiple toilets per plot, so a bit of a proxy
new_toilet_cats = {'UDDT':'Pit Latrine','VIP':'Pit Latrine','disused_buried':'Disused Buried',
                   'flush_inside':'Flush','flush_outside':'Flush','pit_latrine_lined':'Pit Latrine',
                   'pit_latrine_unlined':'Pit Latrine','pour_flush_inside':'Pour Flush','pour_flush_outside':'Pour Flush'}

q2['new_type_of_toilet'] = q2['type_of_toilet'].map(new_toilet_cats)

groups = q2.groupby('new_type_of_toilet')
colours = ['k','g','r','y']

fig, ax = plt.subplots(figsize=(18,12))
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
i=0
for name, group in groups:
    ax.plot(group.longitude, group.latitude, marker='o', linestyle='', ms=2.5, label=name, alpha = 0.5, c=colours[i])
    i = i + 1
ax.legend()
axes = plt.gca()
axes.set_title('Toilet Types by Location')
axes.set_xlabel('Longitude')
axes.set_ylabel('Latitude')
axes.set_xlim([28.205,28.265])
axes.set_ylim([-15.454,-15.417])

plt.show()

# %%
#Location of active non-closed toilets - can have multiple toilets per plot, so a bit of a proxy
active_toilet_cats = {'UDDT':'Operating','VIP':'Operating','disused_buried':'Disused',
                   'flush_inside':'Operating','flush_outside':'Operating','pit_latrine_lined':'Operating',
                   'pit_latrine_unlined':'Operating','pour_flush_inside':'Operating','pour_flush_outside':'Operating'}

q2['active_toilet'] = q2['type_of_toilet'].map(active_toilet_cats)
groups = q2.groupby('active_toilet')
colours = ['b','w']

fig, ax = plt.subplots(figsize=(18,12))
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
i = 0
for name, group in groups:
    ax.plot(group.longitude, group.latitude, marker='o', linestyle='', ms=2.5, label=name, alpha = 0.5, c=colours[i])
    i = i + 1
ax.legend()
axes = plt.gca()
axes.set_title('Disused Toilets')
axes.set_xlabel('Longitude')
axes.set_ylabel('Latitude')
axes.set_xlim([28.205,28.265])
axes.set_ylim([-15.454,-15.417])

plt.show()

# %% [markdown]
# ### Import & Plot transformed plot risk data set

# %%
#Cleansing routine in SQL script: Gather SQL Script

#Risk methodology as follows: 
#Toilet risk: Pit latrine (3), Pour Flush (2), Flush (1), Disused (0)
#User Number Risk: >20 users (3), 10-20 users (2), <10 users (1)
#Assign scores to each plot based on above, then multiply toilet risk by user number risk to obtain compound score.
#Compound score: >6 (Red), >3-6 (Amber), 1-3 (Green), 0 (Disused toilet only)

risk = pd.read_csv('Plot_Risk_Status.csv')
risk.head()
# Out:
#          id  compound_risk   latitude  longitude RAG_Status
# 0  id_00001            NaN        NaN        NaN        NaN
# 1  id_00002            9.0        NaN        NaN        Red
# 2  id_00003            NaN        NaN        NaN        NaN
# 3  id_00004            9.0 -15.431633  28.245173        Red
# 4  id_00005            6.0 -15.430095  28.242203      Amber

# %%
#Plots risk rating
groups = risk.groupby('RAG_Status')
colours = ['y','g','w','r']

fig, ax = plt.subplots(figsize=(18,12))
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
i = 0
for name, group in groups:
    ax.plot(group.longitude, group.latitude, marker='o', linestyle='', ms=2.5, label=name, alpha = 0.5, c=colours[i])
    i = i + 1
ax.legend()
axes = plt.gca()
axes.set_title('RAG Status by Plot')
axes.set_xlabel('Longitude')
axes.set_ylabel('Latitude')
axes.set_xlim([28.205,28.265])
axes.set_ylim([-15.454,-15.417])

plt.show()
